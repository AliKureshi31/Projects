# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\Ali Kureshi\Downloads\Hotel Cancellation Project.csv')

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
for col in df:
    print(df[col].unique())
# Out:
# ['Resort Hotel' 'City Hotel']
# [0 1]
# [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
#  356 142 328 144 336 248 302 175 344 382 146 170 166 338 167 310 148 165
#  172 171 145 121 178 305 173 152 354 347 158 185 349 183 352 177 200 192
# ...

# %%
df = df.replace(np.nan, "other")

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df1=pd.DataFrame(df)

# %%
df1
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df['agent'] = pd.to_numeric(df['agent'], errors='coerce')
mean_agent = df['agent'].mean()
df['agent'] = df['agent'].fillna(mean_agent)

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
df = df.applymap(str)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
df
# Out:
#                hotel is_canceled lead_time arrival_date_year  \
# 0       Resort Hotel           0       342              2015
# 1       Resort Hotel           0       737              2015
# 2       Resort Hotel           0         7              2015
# 3       Resort Hotel           0        13              2015
# 4       Resort Hotel           0        14              2015
# ...              ...         ...       ...               ...
# 119385    City Hotel           0        23              2017
# 119386    City Hotel           0       102              2017
# 119387    City Hotel           0        34              2017
# 119388    City Hotel           0       109              2017
# 119389    City Hotel           0       205              2017
#
#        arrival_date_month arrival_date_week_number arrival_date_day_of_month  \
# 0                    July                       27                         1
# ...

# %%
from sklearn import preprocessing
import pandas as pd
le = preprocessing.LabelEncoder()
df['hotel'] = le.fit_transform(df.hotel.values)
df['arrival_date_month'] = le.fit_transform(df.arrival_date_month.values)
df['customer_type'] = le.fit_transform(df.customer_type.values)
df['reservation_status'] = le.fit_transform(df.reservation_status.values)

# %%
df
# Out:
#         hotel is_canceled lead_time arrival_date_year  arrival_date_month  \
# 0           1           0       342              2015                   5
# 1           1           0       737              2015                   5
# 2           1           0         7              2015                   5
# 3           1           0        13              2015                   5
# 4           1           0        14              2015                   5
# ...       ...         ...       ...               ...                 ...
# 119385      0           0        23              2017                   1
# 119386      0           0       102              2017                   1
# 119387      0           0        34              2017                   1
# 119388      0           0       109              2017                   1
# 119389      0           0       205              2017                   1
#
#        arrival_date_week_number arrival_date_day_of_month  \
# ...

# %%
for column in df.select_dtypes(include=['object']):
    print(column)
#     df= label_encoder.fit_transform(df[['hotel','arrival_date_month','customer_type','reservation_status']])
# Out:
# is_canceled
# lead_time
# arrival_date_year
# arrival_date_week_number
# arrival_date_day_of_month
# stays_in_weekend_nights
# stays_in_week_nights
# adults
# children
# babies
# meal
# country
# market_segment
# distribution_channel
# is_repeated_guest
# previous_cancellations
# previous_bookings_not_canceled
# reserved_room_type
# assigned_room_type
# booking_changes
# deposit_type
# agent
# company
# days_in_waiting_list
# adr
# required_car_parking_spaces
# total_of_special_requests
# reservation_status_date

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
train, test = train_test_split(df, test_size=0.2, random_state=42)

# %%
train
# Out:
#         hotel is_canceled lead_time arrival_date_year  arrival_date_month  \
# 67702       0           1        64              2017                   8
# 115851      0           0        34              2017                   5
# 57345       0           1         8              2016                  11
# 11622       1           1       251              2017                   8
# 33333       1           0        23              2017                   3
# ...       ...         ...       ...               ...                 ...
# 76820       0           0         2              2016                   5
# 110268      0           0        91              2017                   0
# 103694      0           0        74              2016                   2
# 860         1           1       130              2015                   1
# 15795       1           0        16              2015                   5
#
#        arrival_date_week_number arrival_date_day_of_month  \
# ...

# %%
train.reset_index(inplace=True)

# %%
train
# Out:
#         index  hotel is_canceled lead_time arrival_date_year  \
# 0       67702      0           1        64              2017
# 1      115851      0           0        34              2017
# 2       57345      0           1         8              2016
# 3       11622      1           1       251              2017
# 4       33333      1           0        23              2017
# ...       ...    ...         ...       ...               ...
# 95507   76820      0           0         2              2016
# 95508  110268      0           0        91              2017
# 95509  103694      0           0        74              2016
# 95510     860      1           1       130              2015
# 95511   15795      1           0        16              2015
#
#        arrival_date_month arrival_date_week_number arrival_date_day_of_month  \
# 0                       8                       18                         6
# ...

# %%
features = ['hotel', 'lead_time', 'arrival_date_year']  # Replace with actual feature names
target = 'is_canceled'
features
# Out:
# ['hotel', 'lead_time', 'arrival_date_year']

# %%
model = RandomForestRegressor()  # or XGBRegressor()
model.fit(train[features], train[target])
# Out:
# RandomForestRegressor()

# %%
predictions = model.predict(test[features])

# %%
predictions
# Out:
# array([0.56704756, 0.32537834, 0.28876776, ..., 0.19375652, 0.52274649,
#        0.3241877 ])

# %%
mse = mean_squared_error(test[target], predictions)
print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 0.18393747849438735

# %%
test=np.array(test[features])
test
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 test=np.array(test[features])
#       2 test
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
from sklearn.metrics import classification_report
import numpy as np
from sklearn.metrics import confusion_matrix
# print(classification_report(test, predictions))


cm = confusion_matrix(test, predictions)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[127], line 7
#       3 from sklearn.metrics import confusion_matrix
#       4 # print(classification_report(test, predictions))
# ----> 7 cm = confusion_matrix(test, predictions)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
# ...
